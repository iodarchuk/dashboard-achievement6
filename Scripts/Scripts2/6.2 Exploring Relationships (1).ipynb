# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
path = r'C:\Ach 6'
df = pd.read_csv(os.path.join(path, 'Data', 'Original', 'boatdata.csv'), index_col = False)

# %%
# %matplotlib inline

# %%
df.head()
# Out:
#      Price  $ per sqr meter     Boat Type        Manufacturer  \
# 0  3430.70       654.738730    Sport Boat  Marine power boats
# 1  3331.02       642.681845  Fishing Boat  Linder power boats
# 2  3321.50       528.329198    Sport Boat  Linder power boats
# 3  3166.80       543.815362  Fishing Boat  Marine power boats
# 4  4186.00       576.584022      Runabout  Kimple power boats
#
#                   Type  Year Built  Length  Width  Meter Squared   Material  \
# 0  new boat from stock        2007    3.69   1.42         5.2398  Aluminium
# 1  new boat from stock        2019    3.55   1.46         5.1830  Aluminium
# 2  new boat from stock        2007    4.03   1.56         6.2868  Aluminium
# 3  new boat from stock        2007    4.13   1.41         5.8233  Aluminium
# 4  new boat from stock        2020    4.40   1.65         7.2600  Aluminium
#
#                                             Location  \
# 0   Switzerland Ã‚Â» Lake of Zurich Ã‚Â» StÃƒÂ¤fa ZH
# ...

# %%
df.describe()
# Out:
#               Price  $ per sqr meter   Year Built       Length        Width  \
# count  6.991000e+03      6991.000000  6991.000000  6991.000000  6991.000000
# mean   2.591126e+05      4126.992361  2006.861822    11.047986     3.437704
# std    6.885342e+05      3840.767517    12.145461     5.137600     1.116576
# min    3.166800e+03       172.535211  1901.000000     1.980000     0.860000
# 25%    4.221350e+04      1845.318058  2001.000000     7.300000     2.540000
# 50%    8.820000e+04      3029.090909  2008.000000     9.950000     3.210000
# 75%    2.430400e+05      5041.014000  2018.000000    13.500000     4.180000
# max    2.303000e+07     44871.794870  2021.000000    56.000000    16.000000
#
#        Meter Squared  Number of views last 7 days     Latitude    Longitude
# count    6991.000000                  6991.000000  6991.000000  6991.000000
# mean       43.264363                   159.515234    46.588010     8.270586
# ...

# %% [markdown]
# ## Correlations

# %%
df.corr()
# Out:
#                                 Price  $ per sqr meter  Year Built    Length  \
# Price                        1.000000         0.783126    0.117762  0.647125
# $ per sqr meter              0.783126         1.000000    0.323984  0.548592
# Year Built                   0.117762         0.323984    1.000000 -0.097642
# Length                       0.647125         0.548592   -0.097642  1.000000
# Width                        0.563500         0.480116   -0.088981  0.921362
# Meter Squared                0.715627         0.547540   -0.064929  0.959437
# Number of views last 7 days -0.042405        -0.098696   -0.189255 -0.158239
# Latitude                    -0.125775        -0.065383    0.015901 -0.256879
# Longitude                    0.050057         0.010836   -0.066638  0.099221
#
#                                 Width  Meter Squared  \
# Price                        0.563500       0.715627
# $ per sqr meter              0.480116       0.547540
# ...

# %%
f,ax = plt.subplots(figsize=(12,12))

corr = sns.heatmap(df.corr(), annot = True, ax = ax)

# %%
sns.lmplot(x = 'Meter Squared', y = 'Price', data = df)

# %%
sub = df[['Price', 'Year Built', 'Meter Squared', '$ per sqr meter', 'Number of views last 7 days']]

# %%
g = sns.pairplot(sub)
